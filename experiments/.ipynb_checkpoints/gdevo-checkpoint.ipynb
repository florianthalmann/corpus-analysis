# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import gd, main
from corpus_analysis import util
# Out:
# /Users/flo/opt/anaconda3/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:1494: RuntimeWarning: Error importing Gtk module: No module named 'gi'; GTK+ drawing will not work.
#   warnings.warn(msg, RuntimeWarning)

# %%
song = gd.SONGS[9]
versions, dates = gd.get_versions_by_date(song)
essentia_beats = [np.array(e['rhythm']['beats_position']) for e in gd.get_essentias(song)]
madmom_beats = gd.get_beats(song)
essentia_tempos = [60/np.mean(b[1:]-b[:-1]) for b in essentia_beats]
madmom_tempos = [60/np.mean(b[1:]-b[:-1]) for b in madmom_beats]
plt.plot(dates, essentia_tempos)
plt.plot(dates, madmom_tempos)

# %%
essentia_tempos = util.running_mean(essentia_tempos, 10)
madmom_tempos = util.running_mean(madmom_tempos, 10)
plt.plot(dates, essentia_tempos)
plt.plot(dates, madmom_tempos)

# %%
reload(util)
#chords = gd.get_chord_sequences(song)
pchords = main.get_preprocessed_seqs(song)
selection = [i for i,p in enumerate(pchords) if len(p) > 0]
ratio = [len(pchords[i])/len(chords[i]) for i in selection]
pdates = [dates[i] for i in selection]
pchords = [pchords[i] for i in selection]
adjust_time = lambda b,r: np.repeat(b, 2) if r > 1 else odd(b) if r < 1 else b
pmbeats = [adjust_time(madmombeats[i]) for i in selection]
# Out:
# /Users/flo/Projects/Code/Kyoto/corpus_analysis/data/eyes_of_the_world-chords _
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-60a136ebfa64> in <module>
#       1 reload(util)
#       2 #chords = gd.get_chord_sequences(song)
# ----> 3 pchords = main.get_preprocessed_seqs(song)
#       4 selection = [i for i,p in enumerate(pchords) if len(p) > 0]
#       5 ratio = [len(pchords[i])/len(chords[i]) for i in selection]
#
# ~/Projects/Code/Kyoto/corpus-analysis/main.py in get_preprocessed_seqs(song)
#      84 def get_preprocessed_seqs(song):
#      85     sequences = buffered_run(str(os.path.join(DATA, song+'-chords')),
# ---> 86         lambda: get_chord_sequences(song))
#      87     sequences = buffered_run(str(os.path.join(DATA, song+'-pp')),
#      88         lambda: preprocess_sequences(sequences))
#
# ...
